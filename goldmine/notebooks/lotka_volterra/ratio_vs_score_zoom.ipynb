# %% [markdown]
# # Lotka-Volterra simulator: joint ratio vs joint score

# %%
import numpy as np
import corner
from matplotlib import pyplot as plt
# %matplotlib inline
import logging
import matplotlib

from goldmine.simulators.lotka_volterra import LotkaVolterra

logging.basicConfig(format='%(asctime)s  %(message)s', datefmt='%H:%M')
logging.getLogger().setLevel(logging.DEBUG)

# %% [markdown]
# ## Run simulator and collect log r, t

# %%
simulator = LotkaVolterra()
theta0 = simulator.theta_defaults(single_theta=True)[0][0]
print(theta0)
# Out:
# [-4.60517019 -0.69314718  0.         -4.60517019]

# %%
n_thetas = 100
n_samples = 1

# %%
dthetas = []
log_r_xz = []
t_xz = []

for i_theta in range(n_thetas):
    theta1 = simulator.theta_defaults(n_thetas=1)[0][0]
    dtheta = theta1 - theta0
    
    logging.info('\n\n--------------------------------------------------------------------------------\n\n delta theta %s/%s: %s\n\n--------------------------------------------------------------------------------\n', i_theta + 1, n_thetas, dtheta)
    
    x, this_r_xz, this_t_xz = simulator.rvs_ratio_score(theta0, theta1, theta0, theta0, n_samples)
    
    logging.info('\n\nResults: log r = %s, t = %s\n\n', np.log(this_r_xz), this_t_xz)
    
    log_r_xz += list(np.log(this_r_xz))
    t_xz += list(this_t_xz)
    dthetas += [dtheta] * len(this_r_xz)
    
log_r_xz = np.array(log_r_xz)
t_xz = np.array(t_xz)
dthetas = np.array(dthetas)
# Out:
# 15:41
#
# --------------------------------------------------------------------------------
#
#  delta theta 1/100: [-0.00690125  0.00172402  0.00705872 -0.00381658]
#
# --------------------------------------------------------------------------------
#
# 15:41  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61207144 -0.69142316  0.00705872 -4.60898677] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:41    Starting sample 1 of 1
# 15:41
#
# Results: log r = [0.23754582], t = [[-34.95779049  -5.37795648  12.03574869  15.04220951]]
#
#
# 15:41
#
# --------------------------------------------------------------------------------
#
#  delta theta 2/100: [ 0.00489795  0.00171589  0.00939682 -0.00084693]
#
# --------------------------------------------------------------------------------
#
# 15:41  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60027224 -0.69143129  0.00939682 -4.60601711] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:41    Starting sample 1 of 1
# 15:41
#
# Results: log r = [-1.15031762], t = [[-95.69532555  51.77138783 -69.90434568  24.30467445]]
#
#
# 15:41
#
# --------------------------------------------------------------------------------
#
#  delta theta 3/100: [-0.00020183 -0.0042065   0.00640852  0.00040705]
#
# --------------------------------------------------------------------------------
#
# 15:41  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60537202 -0.69735368  0.00640852 -4.60476314] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:41    Starting sample 1 of 1
# 15:41
#
# Results: log r = [-0.05920103], t = [[ 74.79705194 -33.75218823 -24.72151743  26.79705194]]
#
#
# 15:41
#
# --------------------------------------------------------------------------------
#
#  delta theta 4/100: [ 0.0015539   0.00481437 -0.00932223  0.00052757]
#
# --------------------------------------------------------------------------------
#
# 15:41  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60361629 -0.68833281 -0.00932223 -4.60464262] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:41    Starting sample 1 of 1
# 15:41
#
# Results: log r = [0.38299678], t = [[ 39.51490646  22.11429957 -36.00452793 -76.48509354]]
#
#
# 15:41
#
# --------------------------------------------------------------------------------
#
#  delta theta 5/100: [-0.01323079  0.01103902 -0.00354318 -0.01071109]
#
# --------------------------------------------------------------------------------
#
# 15:41  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.
]
#
#
# 15:45
#
# --------------------------------------------------------------------------------
#
#  delta theta 58/100: [-2.10549128e-03 -2.44902952e-05  8.66591480e-03 -4.70032470e-03]
#
# --------------------------------------------------------------------------------
#
# 15:45  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60727568 -0.69317167  0.00866591 -4.60987051] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:45    Starting sample 1 of 1
# 15:45
#
# Results: log r = [0.18534317], t = [[  6.47123182  45.97203474  23.97950724 -14.52876818]]
#
#
# 15:45
#
# --------------------------------------------------------------------------------
#
#  delta theta 59/100: [ 0.00060811 -0.00418617  0.00351681 -0.01020701]
#
# --------------------------------------------------------------------------------
#
# 15:45  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60456208e+00 -6.97333354e-01  3.51681124e-03 -4.61537719e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:45    Starting sample 1 of 1
# 15:45
#
# Results: log r = [0.24621629], t = [[ 57.6454495  -33.70214532  26.08922267  -7.3545505 ]]
#
#
# 15:45
#
# --------------------------------------------------------------------------------
#
#  delta theta 60/100: [-0.00269574 -0.00615681  0.00951894 -0.00984068]
#
# --------------------------------------------------------------------------------
#
# 15:45  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60786592 -0.69930399  0.00951894 -4.61501086] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:45    Starting sample 1 of 1
# 15:45
#
# Results: log r = [0.38740332], t = [[-23.09517191 -25.00892883  -2.37548599 -30.09517191]]
# 15:45
#
# --------------------------------------------------------------------------------
#
#  delta theta 61/100: [-0.0053278   0.00450927 -0.00486253  0.00015624]
#
# --------------------------------------------------------------------------------
#
# 15:45  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61049799 -0.68863791 -0.00486253 -4.60501395] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:45    Starting sample 1 of 1
# 15:45
#
# Results: log r = [0.13860119], t = [[ 31.79693085  42.56372772 -35.37288304   9.79693085]]
#
#
# 15:45
#
# --------------------------------------------------------------------------------
#
#  delta theta 62/100: [ 0.00341705  0.00010886  0.00558904 -0.00891239]
#
# --------------------------------------------------------------------------------
#
# 15:45  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60175313 -0.69303832  0.00558904 -4.61408258] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:45    Starting sample 1 of 1
# 15:45
#
# Results: log r = [0.08892187], t = [[ 20.39493068   9.70240065 -12.83500575 -19.60506932]]
#
#
# 15:45
#
# --------------------------------------------------------------------------------
#
#  delta theta 63/100: [ 0.00089111  0.00216357 -0.00478953 -0.00644109]
#
# --------------------------------------------------------------------------------
#
# 15:45  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60427907 -0.69098361 -0.00478953 -4.61161127] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:45    Starting sample 1 of 1
# 15:46
#
# Results: log r = [0.18817699], t = [[ 20.42879207 -19.9639058   -1.16163823 -37.57120793]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 64/100: [-0.00072895 -0.00607133 -0.00215377  0.00396304]
#
# --------------------------------------------------------------------------------
#
# 15:46  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60589913e+00 -6.99218508e-01 -2.15377442e-03 -4.60120715e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:46    Starting sample 1 of 1
# 15:46
#
# Results: log r = [-0.17748115], t = [[  6.00318595  13.54459033 -35.11284926 -34.99681405]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 65/100: [ 0.00055062  0.01292768 -0.00603934 -0.00388521]
#
# --------------------------------------------------------------------------------
#
# 15:46  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60461956 -0.6802195  -0.00603934 -4.6090554 ] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:46    Starting sample 1 of 1
# 15:46
#
# Results: log r = [0.30328983], t = [[ 58.63804112  19.64538972 -31.83855199   4.63804112]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 66/100: [-0.0092931  -0.00469173 -0.00309154 -0.01329816]
#
# --------------------------------------------------------------------------------
#
# 15:46  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61446329e+00 -6.97838907e-01 -3.09154122e-03 -4.61846834e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:46    Starting sample 1 of 1
# 15:46
#
# Results: log r = [-0.10016471], t = [[ 17.58265502 -17.97675178 -62.18632245   0.58265502]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 67/100: [-0.00231343 -0.00285224 -0.00183103 -0.01399271]
#
# --------------------------------------------------------------------------------
#
# 15:46  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60748361e+00 -6.95999422e-01 -1.83102605e-03 -4.61916290e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:46    Starting sample 1 of 1
# 15:46
#
# Results: log r = [-0.01449998], t = [[ 22.27822748 -27.73479867 -40.38692646  -2.72177252]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 68/100: [ 0.00098467  0.00096434 -0.00158413 -0.01007887]
#
# --------------------------------------------------------------------------------
#
# 15:46  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60418552e+00 -6.92182838e-01 -1.58412545e-03 -4.61524906e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:46    Starting sample 1 of 1
# 15:46
#
# Results: log r = [-0.05374907], t = [[ 22.76295435 -25.8928894   -1.1814392   -0.23704565]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 69/100: [-0.0049218   0.00732363 -0.00489723  0.00076324]
#
# --------------------------------------------------------------------------------
#
# 15:46  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61009198 -0.68582355 -0.00489723 -4.60440694] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:46    Starting sample 1 of 1
# 15:46
#
# Results: log r = [-0.35346559], t = [[-19.74719743 -47.43471511   3.07929901  -8.74719743]]
#
#
# 15:46
#
# --------------------------------------------------------------------------------
#
#  delta theta 70/100: [-0.00515234  0.00704051  0.00273925  0.00431899]
#
# --------------------------------------------------------------------------------
#
# ...
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 78/100: [-0.01450703  0.00652934  0.00559242 -0.00965433]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61967722 -0.68661784  0.00559242 -4.61482452] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [0.50218812], t = [[-26.59704459  -5.30976879 -30.09151148 -65.59704459]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 79/100: [-0.00272349  0.00467004 -0.00216655 -0.00141031]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60789367e+00 -6.88477136e-01 -2.16654671e-03 -4.60658050e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [0.03395337], t = [[-25.88130592 -12.37524067  -1.56901495 -31.88130592]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 80/100: [-1.21847913e-02  1.30504064e-02  4.13648532e-03  2.48601272e-05]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61735498e+00 -6.80096774e-01  4.13648532e-03 -4.60514533e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.80174315], t = [[ -18.55214549  -24.50558021 -114.17033793   30.44785451]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 81/100: [ 2.65966879e-05 -1.98951234e-03  1.39136092e-03 -1.35853922e-02]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60514359e+00 -6.95136693e-01  1.39136092e-03 -4.61875558e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [0.68805041], t = [[-24.42501159  -8.56249597  40.10112893 -52.42501159]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 82/100: [-0.00541035  0.01044191 -0.00067221  0.00321494]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61058054e+00 -6.82705270e-01 -6.72208587e-04 -4.60195525e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.03769147], t = [[ 7.8592267   0.84913436 40.0113419  17.8592267 ]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 83/100: [ 0.00258102  0.00084868  0.00129844 -0.01100026]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60258917e+00 -6.92298499e-01  1.29843843e-03 -4.61617044e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [0.58657126], t = [[ 40.84204301  42.28344118  -0.91545284 -46.15795699]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 84/100: [ 0.00115277  0.00161011 -0.00473007  0.00078144]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60401741 -0.69153707 -0.00473007 -4.60438875] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.03933911], t = [[-5.82313978 -7.84247137 10.45798216 52.17686022]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 85/100: [ 0.00286149  0.01234099 -0.00152046 -0.01043017]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60230870e+00 -6.80806191e-01 -1.52046189e-03 -4.61560036e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-1.15280651], t = [[ 76.69360487 -33.61756711  12.85096398  70.69360487]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 86/100: [-0.00551555  0.0086891   0.00934746 -0.01224568]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61068573 -0.68445808  0.00934746 -4.61741586] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.08358011], t = [[  8.17550723 -34.32626085 -15.56586597 -47.82449277]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 87/100: [-0.00927524  0.00651297 -0.00736174 -0.00256291]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61444543 -0.68663421 -0.00736174 -4.6077331 ] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.33201627], t = [[-23.05880386  18.84409402  63.26431831  20.94119614]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 88/100: [-0.01064927 -0.0037293  -0.00988856 -0.00717483]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61581946 -0.69687648 -0.00988856 -4.61234502] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.67606928], t = [[ 33.94411662  40.29816561 -11.87639249  10.94411662]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 89/100: [-0.01053218  0.00027363  0.00315396  0.00182372]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61570237e+00 -6.92873555e-01  3.15395954e-03 -4.60334647e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [0.21380854], t = [[-16.21580468  19.66429213  22.18444812  21.78419532]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 90/100: [-0.0070797   0.00955617  0.0051264  -0.01181711]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61224988 -0.68359101  0.0051264  -4.61698729] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:47
#
# Results: log r = [-0.51892582], t = [[ 57.45675352   9.10279091 -10.53050633  -4.54324648]]
#
#
# 15:47
#
# --------------------------------------------------------------------------------
#
#  delta theta 91/100: [-0.00559228  0.00468276 -0.005344   -0.01023499]
#
# --------------------------------------------------------------------------------
#
# 15:47  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61076246 -0.68846442 -0.005344   -4.61540518] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:47    Starting sample 1 of 1
# 15:48
#
# Results: log r = [-0.79434379], t = [[16.02058138 10.352736   14.40972793 53.02058138]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 92/100: [ 0.0039711   0.00129377 -0.00709651 -0.00356386]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60119909 -0.69185341 -0.00709651 -4.60873405] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [0.17331084], t = [[-19.1606998    1.62037931 -22.33901073 -42.1606998 ]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 93/100: [ 2.26577491e-03  7.19437963e-05  6.37099060e-03 -1.22949686e-02]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60290441 -0.69307524  0.00637099 -4.61746515] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [1.07692393], t = [[ 89.54917483 -11.69292182 -10.93327633 -88.45082517]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 94/100: [-0.01069114  0.00133709 -0.00100176 -0.0077663 ]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61586133e+00 -6.91810090e-01 -1.00176020e-03 -4.61293648e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [-1.22247449], t = [[ 56.03024634 -45.19921252  -8.36448359  58.03024634]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 95/100: [-0.01218537  0.0106875   0.00214821  0.00018048]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61735555e+00 -6.82459683e-01  2.14820942e-03 -4.60498971e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [-0.27066221], t = [[13.86064924 -1.67262377 16.85598423 45.86064924]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 96/100: [-0.01338418  0.00728445 -0.00877236 -0.00157542]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61855436 -0.68586273 -0.00877236 -4.60674561] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [0.20625154], t = [[  0.04739842   4.55351653 -26.46065201  -2.95260158]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 97/100: [-0.00440661 -0.00663404 -0.00712164 -0.00956321]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60957679 -0.69978122 -0.00712164 -4.6147334 ] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [-0.39541069], t = [[ 48.43278729   1.97928127 -35.73111189  29.43278729]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 98/100: [-0.01328414  0.01226239  0.00404389  0.0042539 ]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61845432e+00 -6.80884789e-01  4.04388996e-03 -4.60091628e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [-0.20902949], t = [[ -0.05475683 -14.377242   -15.5909134   23.94524317]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 99/100: [-0.01333246 -0.00597658 -0.00968626  0.00320401]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.61850264 -0.69912376 -0.00968626 -4.60196618] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [-0.35894485], t = [[ 10.80812878  -5.12477053   6.87996117 -34.19187122]]
#
#
# 15:48
#
# --------------------------------------------------------------------------------
#
#  delta theta 100/100: [ 0.00081403 -0.00089252 -0.00128402 -0.00983271]
#
# --------------------------------------------------------------------------------
#
# 15:48  Simulating 1 evolutions for theta = [-4.60517019 -0.69314718  0.         -4.60517019], augmenting with joint ratio between [-4.60435615e+00 -6.94039696e-01 -1.28402214e-03 -4.61500290e+00] and [-4.60517019 -0.69314718  0.         -4.60517019] and joint score at  [-4.60517019 -0.69314718  0.         -4.60517019]
# 15:48    Starting sample 1 of 1
# 15:48
#
# Results: log r = [0.18522753], t = [[-38.85458267  28.46547002  16.74810712 -34.85458267]]

# %%
dtheta_t_xz = np.diag( dthetas.dot(t_xz.T) )
dtheta_abs = np.linalg.norm(dthetas, axis=1)

# %% [markdown]
# ## Plot delta theta * score vs log r

# %%
fig = plt.figure(figsize=(5,4))
ax = plt.gca()

plt.plot([-10.,10.],[-10.,10.], ls='--', lw=1.5)
sc = plt.scatter((log_r_xz), (dtheta_t_xz),
            c=dtheta_abs, cmap='viridis', norm=matplotlib.colors.LogNorm(vmin=0.00001, vmax=2.),
            s=10.)

cbar = plt.colorbar(sc)

plt.xlabel(r'$\log r$')
plt.ylabel(r'$t \cdot \Delta \theta$')
plt.xlim(-2.,2.)
plt.ylim(-2.,2.)
#ax.set_xscale("log", nonposx='clip')
#ax.set_yscale("log", nonposy='clip')
cbar.set_label(r'$|\Delta \theta|$')

plt.tight_layout()
plt.savefig('lv_local_model_zoom.pdf')

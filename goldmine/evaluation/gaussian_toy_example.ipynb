# %% [markdown]
# # Gaussian toy example

# %%
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.stats import norm

# %% [markdown]
# ## Data

# %%
theta_train = np.load('../data/samples/gaussian/gaussian_train_theta0.npy')
x_train = np.load('../data/samples/gaussian/gaussian_train_x.npy')
log_p_train = np.log(norm.pdf(x_train, loc=theta_train, scale=(1. + theta_train**2)**0.5))
log_p_hat_train = np.load('../data/results/gaussian/maf/gaussian_maf_train_log_p_hat.npy').reshape((-1,1))

theta = np.load('../data/samples/gaussian/gaussian_test_theta0.npy')
x = np.load('../data/samples/gaussian/gaussian_test_x.npy')
log_p = np.log(norm.pdf(x, loc=theta, scale=(1. + 0.25*theta**2)**0.5))
log_p_hat = np.load('../data/results/gaussian/maf/gaussian_maf_test_log_p_hat.npy').reshape((-1,1))

# %%
print(np.mean(log_p_train), np.mean(log_p_hat_train))
print(np.mean(log_p), np.mean(log_p_hat))
# Out:
# -1.7375712490423014 -1.7145102080822832
# -1.7580405730762967 -1.6779875478525879

# %% [markdown]
# ## Plot

# %%
skip=1
fig = plt.figure(figsize=(10,10))



ax = plt.subplot(2,2,1)

plt.scatter(theta_train[::skip], x_train[::skip], c=log_p_train[::skip], cmap='viridis',
            vmin=-3., vmax=-1., s=6.)

plt.xlim(-1.,1,)
plt.ylim(-4.,4.)



ax = plt.subplot(2,2,2)

plt.scatter(theta_train[::skip], x_train[::skip], c=log_p_hat_train[::skip], cmap='viridis',
            vmin=-3., vmax=-1., s=6.)

plt.xlim(-1.,1,)
plt.ylim(-4.,4.)



ax = plt.subplot(2,2,3)

plt.scatter(theta, x, c=log_p, cmap='viridis', vmin=-3., vmax=-1., s=6.)

plt.xlim(-1.,1,)
plt.ylim(-4.,4.)



ax = plt.subplot(2,2,4)

plt.scatter(theta, x, c=log_p_hat, cmap='viridis', vmin=-3., vmax=-1., s=6.)

plt.xlim(-1.,1,)
plt.ylim(-4.,4.)



plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(5,5))

plt.plot([-10.,10.], [-10.,10.], ls='--', lw=1., c='0.5')
plt.scatter(log_p_train, log_p_hat_train, c=theta, cmap='viridis', vmin=-1., vmax=1., s=5.)

plt.xlim(-8.,-1.)
plt.ylim(-8.,-1.)

plt.tight_layout()
plt.show()

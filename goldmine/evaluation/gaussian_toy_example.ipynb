# %% [markdown]
# # Gaussian toy example

# %%
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.stats import norm

# %% [markdown]
# ## Data

# %%
theta_train = np.load('../data/samples/gaussian/gaussian_train_theta0.npy')
x_train = np.load('../data/samples/gaussian/gaussian_train_x.npy')
log_p_train = np.log(norm.pdf(x_train, loc=theta_train, scale=(1. + 0.25*theta_train**2)**2))
log_p_hat_train = np.load('../data/results/gaussian/maf/gaussian_maf_train_log_p_hat.npy').reshape((-1,1))

theta = np.load('../data/samples/gaussian/gaussian_test_theta0.npy')
x = np.load('../data/samples/gaussian/gaussian_test_x.npy')
log_p = np.log(norm.pdf(x, loc=theta, scale=(1. + 0.25*theta**2)**2))
log_p_hat = np.load('../data/results/gaussian/maf/gaussian_maf_test_log_p_hat.npy').reshape((-1,1))

# %% [markdown]
# ## Plot

# %%
fig = plt.figure(figsize=(10,10))



ax = plt.subplot(2,2,1)

plt.scatter(theta_train, x_train, c=log_p_train, cmap='viridis', vmin=-2., vmax=-1.)

plt.xlim(-1.,1,)
plt.ylim(-2.,2.)



ax = plt.subplot(2,2,2)

plt.scatter(theta_train, x_train, c=log_p_hat_train, cmap='viridis', vmin=-2., vmax=-1.)

plt.xlim(-1.,1,)
plt.ylim(-2.,2.)



ax = plt.subplot(2,2,3)

plt.scatter(theta, x, c=log_p, cmap='viridis', vmin=-2., vmax=-1.)

plt.xlim(-1.,1,)
plt.ylim(-2.,2.)



ax = plt.subplot(2,2,4)

plt.scatter(theta, x, c=log_p_hat, cmap='viridis', vmin=-2., vmax=-1., s=6.)

plt.xlim(-1.,1,)
plt.ylim(-2.,2.)



plt.tight_layout()
plt.show()
